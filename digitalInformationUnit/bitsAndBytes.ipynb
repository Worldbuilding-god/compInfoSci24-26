# %% [markdown]
# # BITS AND BYTES

# %% [markdown]
# BIT = SMALLEST PART OF DATA
#
# BYTE = 8 BITS
#
# ## REPRESENTING COLOR
#
# hex - #** ** **
#
# rgb - (**, **, **)

# %% [markdown]
# ### SERIES OF BITS
#
# 2 bits - 00 01 10 11
#
# 3 bits - 000 001 010 011 100 101 110 111

# %% [markdown]
# ## Bytes = 8 bits

# %% [markdown]
# ## Visualize numbers in decimal

# %% [markdown]
# 100's + 10's + 1's
#
# ## Binary
#
# ect's + 8's + 4's + 2's + 1's
#
# 1001 = 9

# %% [markdown]
# ## Storing numbers

# %% [markdown]
# 0   0   0   0 <br>
# -/+ 4   2   1

# %% [markdown]
# OVERFLOW - When a computer reaches it's limit, and it rolls over

# %% [markdown]
# ## MODERN COMPTUERS USE 64 BITS
#
# # 9,007,199,254,740,991 - 1 OR 2^53 - 1 !

# %% [markdown]
# ## FLOATING POINT!!!

# %% [markdown]
# HARDER TO DO!
# 2/5?!<br>
# 1.234?!<br>
# 9.999999999999999999?!<br>
# 3.141592654?!<br>

# %% [markdown]
# computers use floating point representation.
#
# A number is multiplied by a base raised to an exponent<br>
# 300 = 3 x 10^2
#
# BINARY: 128 = 1 x 2^7

# %% [markdown]
# numbers between powers of 2
#
# 160 = 1.25 x 2^7
#
# 192 = 150 x 2^7
#
# 224 = 1.75 x 2^7

# %% [markdown]
# ## WHAT ABOUT NON INTEGERS!?
#
# 0.50 = 1 x 2^-1
#
# 0.25 = 1 x 2^-2
#
# ## Floating points!?
#
# 0.750 = 1.5 x 2^-2
#
# 0.375 = 1.5 x 2^-2 = BIG BINARY NUMBER!

# %% [markdown]
# ### round off errors

# %% [markdown]
# All floating point numbers cant be fully represented using binary.
#
# 1/3 = 0.33333333...
#
# 1/3 = 1.3 x 2^-2 --> .010101010101...

# %%
result = 0.1 + 0.1 + 0.1
print(result)
# Out:
# 0.30000000000000004

# %% [markdown]
# More bits = more precision.
